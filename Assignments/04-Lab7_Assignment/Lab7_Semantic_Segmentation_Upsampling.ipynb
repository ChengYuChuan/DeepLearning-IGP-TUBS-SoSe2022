# %% [markdown]
# **Course**: Deep Learning
#
# [<img align="right" width="400" height="100" src="https://www.tu-braunschweig.de/typo3conf/ext/tu_braunschweig/Resources/Public/Images/Logos/tu_braunschweig_logo.svg">](https://www.tu-braunschweig.de/en/)
#
# [Mehdi Maboudi](https://www.tu-braunschweig.de/en/igp/staff/mehdi-maboudi) \([m.maboudi@tu-bs.de](m.maboudi@tu-bs.de)) and [Pedro Achanccaray](https://www.tu-braunschweig.de/en/igp/staff/pedro-diaz) (p.diaz@tu-bs.de)
#
# [Technical University of Braunschweig](https://www.tu-braunschweig.de/en/)
# [Institute of Geodesy and Photogrammetry](https://www.tu-braunschweig.de/igp)

# %% [markdown]
# # Lab 7: Semantic Segmentation
#
# In this lab session, we will cover the following topics:
# - Dataset: 2D Semantic Labeling - Vaihingen data
# - DataGenerator for Image Segmentation
# - U-Net

# %% [markdown]
# ## Mount Google Drive to Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/Colab Notebooks/Deep learning task
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Colab Notebooks/Deep learning task'
# /content/drive/MyDrive/Colab Notebooks/Deep learning task

# %% [markdown]
# # Import packages

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, BatchNormalization
from tensorflow.keras.layers import Conv2DTranspose, concatenate, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.metrics import OneHotMeanIoU, OneHotIoU
# Callbacks
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Visualization
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as patches
# Operation with arrays
import numpy as np
# Paths and files
from os.path import join,basename,splitext
import os
from glob import glob
from natsort import natsorted
# Reading images
import tifffile
from PIL import Image
# Others
import random

# %% [markdown]
# ## Dataset

# %% [markdown]
# We will work with the ISPRS [2D Semantic Labeling benchmark - Vaihingen](https://www.isprs.org/education/benchmarks/UrbanSemLab/2d-sem-label-vaihingen.aspx).
#
# The dataset contains 33 patches (of different sizes), each consisting of a true orthophoto (TOP), extracted from a larger TOP mosaic, and a Digital Surface Model (DSM).
#
# <center>
# <img width=500 src="https://www.isprs.org/education/benchmarks/UrbanSemLab/img/overview_tiles.jpg?width=398.4830805134189&height=500" img>
# </center>
#
# Labelled ground truth is provided for all areas. An example of a patch from the dataset, where a) true orthophoto, b) DSM, and c) ground truth.
#
# <center>
# <img width=600 src="https://www.isprs.org/education/benchmarks/UrbanSemLab/img/examples_top_dsm_gts.png?width=500&height=196.7930029154519" img>
# </center>

# %% [markdown]
# ### Loading the data
#
# To create the train, validation and test sets, we will follow the benchmark guidelines:
#
# <center>
# <img width=600 src="https://www.isprs.org/education/benchmarks/UrbanSemLab/img/table_label_contest_image_overview.png?width=500&height=397.5490196078431" img>
# </center>
#
# So, the areas for training and testing are the following:
#
# |  Set  |   Areas   |
# |-------|-----------|
# | Train | 1,3,5,7,11,13,15,17,21,23,26,28,30,32,34,37 |
# | Test  | 2,4,6,8,10,12,14,16,20,22,24,27,29,31,33,35,38 |

# %% [markdown]
# The folder structure is the following:
#
# - _dsm_: Digital Surface Models with information about the height of each geographical area.
# - _gts_: Ground Truths or References with information about the semantic class of each pixel.
# - _top_: True Orthophoto with a False RGB Color composition with near infrared, red and green bands.

# %%
# install tree package for better visualization of folder structure
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (167 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree -d
# Out:
# .
# ├── Dataset
# ├── hymenoptera_data
# │   ├── train
# │   │   ├── ants
# │   │   └── bees
# │   └── val
# │       ├── ants
# │       └── bees
# ├── Image_Dataset
# │   ├── AnnualCrop
# │   ├── Forest
# │   ├── HerbaceousVegetation
# │   ├── Highway
# │   ├── Industrial
# │   ├── Pasture
# │   ├── PermanentCrop
# │   ├── Residential
# │   ├── River
# │   └── SeaLake
# ├── ISPRS_semantic_labeling_Vaihingen
# │   ├── dsm
# │   ├── gts
# │   └── top
# └── TransferLearningLog
#
# 24 directories

# %% [markdown]
# Reading all images from the _top_, _dsm_ and _gts_ folders

# %%
# Path to the dataset folder in Google Drive
root_path = "ISPRS_semantic_labeling_Vaihingen"
path_top = join(root_path,"top")
path_dsm = join(root_path,"dsm")
path_gts = join(root_path,"gts")

# List with all TIF images in each folder
list_top = glob(join(path_top,"*.tif"))
list_top = natsorted(list_top, key=lambda y: y.lower())

list_dsm = glob(join(path_dsm,"*.tif"))
list_dsm = natsorted(list_dsm, key=lambda y: y.lower())

list_gts = glob(join(path_gts,"*.tif"))
list_gts = natsorted(list_gts, key=lambda y: y.lower())

# %% [markdown]
# ### Train, Validation and Test
# Let's create the train, validation and test sets

# %%
# Images IDs for train and test
train_ids = [1,3,5,7,11,13,15,17,21,23,26,28,30,32,34,37]
test_ids = [2,4,6,8,10,12,14,16,20,22,24,27,29,31,33,35,38]

list_top_train, list_top_val, list_top_test = ([] for i in range(3))
list_dsm_train, list_dsm_val, list_dsm_test = ([] for i in range(3))
list_gts_train, list_gts_val, list_gts_test = ([] for i in range(3))

# %%
for top,dsm,gts in zip(list_top,list_dsm,list_gts):
  # Get the aread ID from the filename
  area_id = int(splitext(basename(top))[0].split("area")[-1])
  # Train set
  if area_id in train_ids:    
    list_top_train.append(top)
    list_dsm_train.append(dsm)
    list_gts_train.append(gts)
  # Test set
  elif area_id in test_ids:    
    list_top_test.append(top)
    list_dsm_test.append(dsm)
    list_gts_test.append(gts)

# shuffle train lists
temp = list(zip(list_top_train,list_dsm_train,list_gts_train))
random.seed(10)
random.shuffle(temp)
list_top_train,list_dsm_train,list_gts_train = zip(*temp)

# take 25% as validation set
p_val = 0.25
n_val = int(p_val*len(list_top_train))

list_top_val = list_top_train[:n_val]
list_top_train = list_top_train[n_val:]

list_dsm_val = list_dsm_train[:n_val]
list_dsm_train = list_dsm_train[n_val:]

list_gts_val = list_gts_train[:n_val]
list_gts_train = list_gts_train[n_val:]

# %% [markdown]
# ### Dataset information

# %%
def print_info(list_top,list_dsm,list_gts):
  for top,dsm,gts in zip(list_top,list_dsm,list_gts):
    gt_temp = tifffile.imread(gts)
    n_classes = len(np.unique(gt_temp.reshape(gt_temp.shape[0]*gt_temp.shape[1],-1),axis=0))
    print("TOP:{} , DSM:{} , GT:{} , N:{}".format(basename(top),
                                  basename(dsm),
                                  basename(gts),
                                  n_classes))

# %% [markdown]
# Let's see the number of classes in each image.
#
# **It is very important that all sets have samples of all classes.**

# %%
# Train
print("Train:")
print_info(list_top_train,list_dsm_train,list_gts_train)

# Validation
print("\nValidation:")
print_info(list_top_val,list_dsm_val,list_gts_val)

# Test
print("\nTest:")
print_info(list_top_test,list_dsm_test,list_gts_test)
# Out:
# Train:
# TOP:top_mosaic_09cm_area28.tif , DSM:dsm_09cm_matching_area28.tif , GT:top_mosaic_09cm_area28.tif , N:6
# TOP:top_mosaic_09cm_area37.tif , DSM:dsm_09cm_matching_area37.tif , GT:top_mosaic_09cm_area37.tif , N:5
# TOP:top_mosaic_09cm_area13.tif , DSM:dsm_09cm_matching_area13.tif , GT:top_mosaic_09cm_area13.tif , N:5
# TOP:top_mosaic_09cm_area11.tif , DSM:dsm_09cm_matching_area11.tif , GT:top_mosaic_09cm_area11.tif , N:5
# TOP:top_mosaic_09cm_area30.tif , DSM:dsm_09cm_matching_area30.tif , GT:top_mosaic_09cm_area30.tif , N:5
# TOP:top_mosaic_09cm_area32.tif , DSM:dsm_09cm_matching_area32.tif , GT:top_mosaic_09cm_area32.tif , N:6
# TOP:top_mosaic_09cm_area7.tif , DSM:dsm_09cm_matching_area7.tif , GT:top_mosaic_09cm_area7.tif , N:5
# TOP:top_mosaic_09cm_area1.tif , DSM:dsm_09cm_matching_area1.tif , GT:top_mosaic_09cm_area1.tif , N:6
# TOP:top_mosaic_09cm_area23.tif , DSM:dsm_09cm_matching_area23.tif , GT:top_mosaic_09cm_area23.tif , N:6
# TOP:top_mosaic_09cm_area17.tif , DSM:dsm_09cm_matching_area17.tif , GT:top_mosaic_09cm_area17.tif , N:5
# TOP:top_mosaic_09cm_area15.tif , DSM:dsm_09cm_matching_area15.tif , GT:top_mosaic_09cm_area15.tif , N:6
# TOP:top_mosaic_09cm_area3.tif , DSM:dsm_09cm_matching_area3.tif , GT:top_mosaic_09cm_area3.tif , N:5
#
# Validation:
# TOP:top_mosaic_09cm_area5.tif , DSM:dsm_09cm_matching_area5.tif , GT:top_mosaic_09cm_area5.tif , N:5
# TOP:top_mosaic_09cm_area21.tif , DSM:dsm_09cm_matching_area21.tif , GT:top_mosaic_09cm_area21.tif , N:5
# TOP:top_mosaic_09cm_area34.tif , DSM:dsm_09cm_matching_area34.tif , GT:top_mosaic_09cm_area34.tif , N:5
# TOP:top_mosaic_09cm_area26.tif , DSM:dsm_09cm_matching_area26.tif , GT:top_mosaic_09cm_area26.tif , N:6
#
# Test:
# TOP:top_mosaic_09cm_area2.tif , DSM:dsm_09cm_matching_area2.tif , GT:top_mosaic_09cm_area2.tif , N:6
# TOP:top_mosaic_09cm_area4.tif , DSM:dsm_09cm_matching_area4.tif , GT:top_mosaic_09cm_area4.tif , N:5
# TOP:top_mosaic_09cm_area6.tif , DSM:dsm_09cm_matching_area6.tif , GT:top_mosaic_09cm_area6.tif , N:5
# TOP:top_mosaic_09cm_area8.tif , DSM:dsm_09cm_matching_area8.tif , GT:top_mosaic_09cm_area8.tif , N:5
# TOP:top_mosaic_09cm_area10.tif , DSM:dsm_09cm_matching_area10.tif , GT:top_mosaic_09cm_area10.tif , N:5
# TOP:top_mosaic_09cm_area12.tif , DSM:dsm_09cm_matching_area12.tif , GT:top_mosaic_09cm_area12.tif , N:5
# TOP:top_mosaic_09cm_area14.tif , DSM:dsm_09cm_matching_area14.tif , GT:top_mosaic_09cm_area14.tif , N:5
# TOP:top_mosaic_09cm_area16.tif , DSM:dsm_09cm_matching_area16.tif , GT:top_mosaic_09cm_area16.tif , N:5
# TOP:top_mosaic_09cm_area20.tif , DSM:dsm_09cm_matching_area20.tif , GT:top_mosaic_09cm_area20.tif , N:6
# TOP:top_mosaic_09cm_area22.tif , DSM:dsm_09cm_matching_area22.tif , GT:top_mosaic_09cm_area22.tif , N:5
# TOP:top_mosaic_09cm_area24.tif , DSM:dsm_09cm_matching_area24.tif , GT:top_mosaic_09cm_area24.tif , N:5
# TOP:top_mosaic_09cm_area27.tif , DSM:dsm_09cm_matching_area27.tif , GT:top_mosaic_09cm_area27.tif , N:6
# TOP:top_mosaic_09cm_area29.tif , DSM:dsm_09cm_matching_area29.tif , GT:top_mosaic_09cm_area29.tif , N:6
# TOP:top_mosaic_09cm_area31.tif , DSM:dsm_09cm_matching_area31.tif , GT:top_mosaic_09cm_area31.tif , N:6
# TOP:top_mosaic_09cm_area33.tif , DSM:dsm_09cm_matching_area33.tif , GT:top_mosaic_09cm_area33.tif , N:6
# TOP:top_mosaic_09cm_area35.tif , DSM:dsm_09cm_matching_area35.tif , GT:top_mosaic_09cm_area35.tif , N:5
# TOP:top_mosaic_09cm_area38.tif , DSM:dsm_09cm_matching_area38.tif , GT:top_mosaic_09cm_area38.tif , N:5

# %% [markdown]
# ### Visualization of dataset samples

# %%
#@title Samples Visualization { run: "auto"}
#@markdown Select a sample
id_sample = 28 #@param {type:"slider", min:0, max:32, step:1}
img_top = tifffile.imread(list_top[id_sample])
img_dsm = tifffile.imread(list_dsm[id_sample])

print("Image: {}".format(list_top[id_sample]))

plt.figure(figsize=(15,5))

plt.subplot(1,4,1)
plt.imshow(img_top)
plt.title("RGB False Color composition\n{}\
          \nMin:{}, Max:{}".format(img_top.shape,
                                     img_top.min(),
                                     img_top.max()))
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(img_dsm, cmap="gray")
plt.title("Digital Surface Model\
            \nMin:{:.2f}, Max:{:.2f}".format(img_dsm.min(),
                                             img_dsm.max()))
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(tifffile.imread(list_gts[id_sample]))
plt.title("Ground Truth")
plt.axis("off")

g = plt.subplot(1,4,4)
g.axes.set_xlim(0,3.4)
g.axes.set_ylim(-0.01,0.55)

g.text(0, 0.025, "Impervious surfaces")
g.text(0, 0.125, "Building ")
g.text(0, 0.225, "Low vegetation")
g.text(0, 0.325, "Tree ")
g.text(0, 0.425, "Car ")
g.text(0, 0.525, "Clutter/background")

x_rec = 2.3
g.add_patch(patches.Rectangle((x_rec,0.0), 1, 0.05, facecolor="#FFFFFF", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.1), 1, 0.05, facecolor="#0000FF", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.2), 1, 0.05, facecolor="#00FFFF", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.3), 1, 0.05, facecolor="#00FF00", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.4), 1, 0.05, facecolor="#FFFF00", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.5), 1, 0.05, facecolor="#FF0000", edgecolor="black"))
g.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Image: ISPRS_semantic_labeling_Vaihingen/top/top_mosaic_09cm_area33.tif

# %% [markdown]
# ### Classes
# Dictionary to represent each color and its corresponding class.

# %%
color2index = {(255,255,255) : 0,
               (0  ,0  ,255) : 1,
               (0  ,255,255) : 2,
               (0  ,255,0  ) : 3,
               (255,255,0  ) : 4,
               (255,0  ,0  ) : 5
               }
n_classes = len(color2index)

# %% [markdown]
# ## Data Generator

# %% [markdown]
# Requirements of the model:
#
# - **Input:** Image $[height×width×bands]$
# - **Output:** Image $[height×width×classes]$
#
# As the images are too big, we will extract patches with a size $[p×p]$ and step (stride) $s$.
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1UYrpG-sD_UGCRR7Ras73THF-sbqQoGTu" width=100 img>
# </center>
#
#
# Data Generator parameters:
# - _batch_size_: number of samples per batch
# - _patch_size_: size of the patch extracted from the image
# - _step_size_: step to extract patches from the image
# - _list_top_: list with paths of RGB images
# - _list_dsm_: list with paths of DSM images
# - _list_gts_: list with paths of GT images
# - _n_classes_: number of classes
# - _colormap_gt_: dictionary with the colormap to convert RGB image $[H×W×3]$ to label image $[H×W×1]$
#
# **Recommendation:** Use [Pillow](https://pillow.readthedocs.io/en/stable/) to reduce processing time in reading and cropping the image, because it just loads the part of the image specified by the method [crop](https://pillow.readthedocs.io/en/stable/reference/ImageOps.html?highlight=crop#PIL.ImageOps.crop) when it is converted to a numpy array (_np.asarray_).
#
# ```python
# # Just reading the header of the image with its information
# data = Image.open(path)
# # Cropping the area of the image
# data = data.crop((x, y, x+patch_size, y+patch_size)
# # Loads only the cropped area of the image
# data = np.asarray(data)
# ```

# %%
class DataGenerator(keras.utils.Sequence):
  def __init__(self,
               batch_size,
               patch_size,
               step_size,
               list_top,                
               list_gts,
               n_classes,
               colormap_gt=None,
               augmentation=None,
               preprocessing=None,               
               shuffle=True):
    self.batch_size = batch_size
    self.patch_size = patch_size
    self.step_size = step_size
    self.list_top = list_top    
    self.list_gts = list_gts
    self.n_classes = n_classes
    self.colormap_gt = colormap_gt
    self.augmentation = augmentation
    self.preprocessing = preprocessing        
    self.shuffle= shuffle
    self.path_coords = self.__get_path_coords()
    self.n_patchs = len(self.path_coords)

  def __get_path_coords(self):
    path_coords = []    
    for path_image, path_label in zip(self.list_top,self.list_gts):       
      width, height = Image.open(path_label).size      
      for y in range(0, height, self.step_size):
        for x in range(0, width, self.step_size):
          if (x + self.patch_size) > width:
            x = width - self.patch_size
          if (y + self.patch_size) > height:
            y = height - self.patch_size
          
          path_coords.append((path_image, path_label, (x,y)))          
    return path_coords
        
  def on_epoch_end(self):
    if self.shuffle:
      random.shuffle(self.path_coords)

  def __len__(self):
    return np.ceil(self.n_patchs/self.batch_size).astype("int")

  def __get_patch_image(self, path_image, x, y):
    # Reading the RGB image
    data_image = Image.open(path_image)
    data_image = data_image.crop((x, y, 
                                  x + self.patch_size, y + self.patch_size))
    data_image = np.asarray(data_image).astype("float32")
    
    return data_image/255.0

  def __get_patch_mask(self, path, x, y):
    # Reading the mask
    data_mask = Image.open(path)
    data_mask = data_mask.crop((x, y, 
                                x + self.patch_size, y + self.patch_size))
    data_mask = np.asarray(data_mask)
    # Convert RGB image [H x W x 3] to label image [H x W x 1]
    data_mask_idx = np.zeros((data_mask.shape[0], 
                              data_mask.shape[1]), dtype=np.uint8)
    for key in self.colormap_gt:
      class_id = self.colormap_gt[key]
      key = np.array(key)
      # Assign an index to each color based on the colormap
      # (255,255,255) : 0
      # (0  ,0  ,255) : 1,...
      data_mask_idx[(data_mask[:,:,0] == key[0]) & 
                    (data_mask[:,:,1] == key[1]) & 
                    (data_mask[:,:,2] == key[2])] = class_id
    return data_mask_idx

  def __getitem__(self, idx):
    i = idx * self.batch_size
    
    current_batch_size = self.batch_size
    if (idx+1) == self.__len__():
      current_batch_size = len(self.path_coords[i:])

    # Batch of coordinates
    batch_path_coords = self.path_coords[i : i + current_batch_size]

    x = np.zeros((current_batch_size, 
                  self.patch_size, 
                  self.patch_size, 
                  3),
                  dtype=np.float32)

    y = np.zeros((current_batch_size,
                  self.patch_size, 
                  self.patch_size,
                  self.n_classes),
                  dtype=np.float32)

    for j, (path_image, path_label, (x_pos, y_pos)) in enumerate(batch_path_coords):
      # Get an individual image and its corresponding label
      x_sample = self.__get_patch_image(path_image, x_pos, y_pos)
      y_sample = self.__get_patch_mask(path_label, x_pos, y_pos)        
      
      # If there are augmentation transformations, apply them
      if self.augmentation is not None:
        augmented = self.augmentation()(image=x_sample, mask=y_sample)
        x_sample = augmented["image"]
        y_sample = augmented["mask"]
      # If there is a preprocessing function, apply it
      if self.preprocessing is not None:
        preprocessed = self.preprocessing(image=x_sample, mask=y_sample)
        x_sample = preprocessed['image']
        y_sample = preprocessed['mask']
      # Convert labels to one hot encoding
      y_sample = to_categorical(y_sample, self.n_classes)

      x[j,...] = x_sample
      y[j,...] = y_sample
    return x, y

# %% [markdown]
# Create a temporal generator just to verify the output of our class DataGenerator and visualize a batch.

# %%
# Temporal generator
temp_generator = DataGenerator(batch_size=4,
                         patch_size=256,
                         step_size=256,
                         list_top=list_top_train, 
                         list_gts=list_gts_train,
                         n_classes=n_classes,
                         colormap_gt=color2index
                         )
# Iterate over all batches
for x,y in temp_generator:
  # Check the shape of the output of the generator
  print(x.shape, y.shape)
  for x_i,y_i in zip(x,y):
    # For visualization: [0,1] => [0,255]
    x_i = x_i*255
    # Apply argmax to convert from one hot to integers
    y_i = np.argmax(y_i, axis=-1)
    # Convert each class to a color given a colormap
    y_i_rgb = np.zeros((y_i.shape[0], y_i.shape[1], 3), dtype=np.uint8)
    for key,value in color2index.items():
      y_i_rgb[y_i==value] = key      
    # Visualization of RGB image and its ground truth or reference
    plt.figure(figsize=(10,10))
    plt.subplot(1,2,1)
    plt.imshow(x_i.astype("uint8"))
    plt.title("RGB Image")
    plt.axis("off")

    plt.subplot(1,2,2)
    plt.imshow(y_i_rgb, cmap="jet")
    plt.title("Ground Truth")
    plt.axis("off")
    plt.show()
  break
# Out:
# (4, 256, 256, 3) (4, 256, 256, 6)

# %% [markdown]
# ### DataGenerator for train and validation

# %% [markdown]
# Let's create the generators for training and validation:
# - $batch\_size=8$
# - $patch\_size=256$
# - $step\_size=256$

# %%
batch_size = 8
patch_size = 256
step_size = 256

data_gen_train = DataGenerator(batch_size=batch_size,
                               patch_size=patch_size,
                               step_size=step_size,
                               list_top=list_top_train, 
                               list_gts=list_gts_train,
                               n_classes=n_classes,
                               colormap_gt=color2index
                               )

data_gen_val = DataGenerator(batch_size=batch_size,
                             patch_size=patch_size,
                             step_size=step_size,
                             list_top=list_top_val, 
                             list_gts=list_gts_val,
                             n_classes=n_classes,
                             colormap_gt=color2index
                             )

# %% [markdown]
# Number of batches in each set:

# %%
print("Train: {}, Validation: {}".format(len(data_gen_train), len(data_gen_val)))
# Out:
# Train: 128, Validation: 38

# %% [markdown]
# ## Semantic Segmentation models
# We will use the U-Net model for multiclass semantic segmentation.
#
# <center>
# <img width=700 src="https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png" img>
# </center>
#
# Code based on [U-Net image segmentation in Keras](https://pyimagesearch.com/2022/02/21/u-net-image-segmentation-in-keras/)

# %% [markdown]
# Functions with block to build a U-Net:
# - _conv_block_: convolutional block with only multiple convolutions.
# - _downsampling_: downsampling block with a series of convolutions, a max pooling and dropout layers.
# - _upsampling_: upsampling block with a transpose convolution, concatenate a feature map, dropout and a series of convolutions.

# %%
def conv_block(x, n_filters, times=2):
  for i in range(times):
    x = Conv2D(filters=n_filters, 
              kernel_size=3, 
              strides=1, 
              padding="same", 
              activation="relu", 
              kernel_initializer="he_normal")(x)
  return x

def downsampling(x, n_filters, times=2):
  feat = conv_block(x, n_filters, times=times)  
  pool = MaxPooling2D(pool_size=2)(feat)
  pool = Dropout(rate=0.3)(pool)
  return feat,pool

def upsampling(input, filters, layer_concat=None):
  x = UpSampling2D(size=(2, 2),
              interpolation="nearest")(input)
  if layer_concat is not None:
    x = concatenate([x, layer_concat])
  x = Dropout(rate=0.3)(x)  
  x = conv_block(x, filters, times=2)
  return x

# %% [markdown]
# Building the U-Net model.
#
# _Notice that the original model has a bottleneck area with **1024** features, we are only using **512** for this example._

# %%
def get_unet(img_size, n_classes):
  # Input
  input = Input(shape=(img_size,img_size,3))
  # Downsampling
  f1,p1 = downsampling(input, 64, times=2)
  f2,p2 = downsampling(p1, 128, times=2)
  f3,p3 = downsampling(p2, 256, times=2)
  # Bottleneck
  blottleneck = conv_block(p3, 512, times=2)
  #Upsampling  
  u7 = upsampling(blottleneck, 256, layer_concat=f3)
  u8 = upsampling(u7, 128, layer_concat=f2)
  u9 = upsampling(u8, 64, layer_concat=f1)
  # Output
  output = Conv2D(filters=n_classes, 
                  kernel_size=1, 
                  padding="same", 
                  activation="softmax")(u9)
  model = Model(inputs=input, outputs=output, name="UNet")

  return model

# %%
model_unet = get_unet(img_size=patch_size, 
                    n_classes=n_classes)

# %% [markdown]
# ### Visualization of U-Net

# %%
model_unet.summary()
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 64  1792        ['input_4[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_31[0][0]']
#                                 )
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_32[0][0]']
#                                 )
#
#  dropout_12 (Dropout)           (None, 128, 128, 64  0           ['max_pooling2d_9[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 12  73856       ['dropout_12[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_33[0][0]']
#                                 8)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 64, 64, 128)  0          ['conv2d_34[0][0]']
#  )
#
#  dropout_13 (Dropout)           (None, 64, 64, 128)  0           ['max_pooling2d_10[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 256)  295168      ['dropout_13[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_35[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 32, 32, 256)  0          ['conv2d_36[0][0]']
#  )
#
#  dropout_14 (Dropout)           (None, 32, 32, 256)  0           ['max_pooling2d_11[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 512)  1180160     ['dropout_14[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_37[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 512)  0           ['conv2d_38[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  dropout_15 (Dropout)           (None, 64, 64, 768)  0           ['concatenate_3[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 256)  1769728     ['dropout_15[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_39[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['conv2d_40[0][0]']
#                                 6)
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'conv2d_34[0][0]']
#
#  dropout_16 (Dropout)           (None, 128, 128, 38  0           ['concatenate_4[0][0]']
#                                 4)
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 12  442496      ['dropout_16[0][0]']
#                                 8)
#
#  conv2d_42 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_41[0][0]']
#                                 8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 12  0          ['conv2d_42[0][0]']
#                                 8)
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'conv2d_32[0][0]']
#
#  dropout_17 (Dropout)           (None, 256, 256, 19  0           ['concatenate_5[0][0]']
#                                 2)
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 64  110656      ['dropout_17[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_43[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 6)  390         ['conv2d_44[0][0]']
#
# ==================================================================================================
# Total params: 7,783,238
# Trainable params: 7,783,238
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_unet, to_file="model_unet_2.png", show_shapes=True)

# %% [markdown]
# <center>
# <img src="https://drive.google.com/uc?export=view&id=11YoRuP0iYXMJYcOmTWAc35LE53D2keNI" width=900 img>
# </center>

# %% [markdown]
# ### Training configuration

# %% [markdown]
# We will use _Intersection over Union (IoU)_ as metric to be monitored during training.
#
# As the labels are in _one hot_ encoding, we can use the _one hot_ version of _mean IoU_: [OneHotMeanIoU](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/OneHotMeanIoU).
#
# Also, to assess the model, we will compute the IoU per class in the test set, so we can use: [OneHotIoU](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/OneHotIoU) per class.

# %%
model_unet.compile(optimizer=Adam(),
                  loss="categorical_crossentropy",
                  metrics=["accuracy", OneHotMeanIoU(num_classes=n_classes, name="iou")])

# %% [markdown]
# ### Callbacks

# %% [markdown]
# Function to save checkpoints for each model

# %%
def get_ckpt(ckpt_name):
    return ModelCheckpoint(ckpt_name,
                           mode="max", 
                           save_best_only=True, 
                           monitor="val_iou", 
                           verbose=1)

# %% [markdown]
# Callbacks definition to be executed during training

# %%
# Callbacks
# Checkpoint
autosave_unet = get_ckpt("segmentation_unet.h5")

# Early stopping
early_stopping = EarlyStopping(patience=30, verbose=1, mode = 'auto')

cbks_unet = [autosave_unet, early_stopping]

# %%
epochs = 200

# %% [markdown]
# ### Training

# %%
history_unet = model_unet.fit(data_gen_train,
                              epochs=epochs,                                                     
                              validation_data=data_gen_val,                                                    
                              callbacks=cbks_unet,
                              workers=4, 
                              use_multiprocessing=True,
                              max_queue_size=20
                              )
# Out:
# Epoch 1/200
# 128/128 [==============================] - ETA: 0s - loss: 1.2889 - accuracy: 0.5206 - iou: 0.2374
# Epoch 1: val_iou improved from -inf to 0.32515, saving model to segmentation_unet.h5
# 128/128 [==============================] - 110s 676ms/step - loss: 1.2889 - accuracy: 0.5206 - iou: 0.2374 - val_loss: 0.9315 - val_accuracy: 0.6540 - val_iou: 0.3251
# Epoch 2/200
# 128/128 [==============================] - ETA: 0s - loss: 0.8526 - accuracy: 0.6473 - iou: 0.3209
# Epoch 2: val_iou improved from 0.32515 to 0.37519, saving model to segmentation_unet.h5
# 128/128 [==============================] - 97s 740ms/step - loss: 0.8526 - accuracy: 0.6473 - iou: 0.3209 - val_loss: 0.8646 - val_accuracy: 0.7161 - val_iou: 0.3752
# Epoch 3/200
# 128/128 [==============================] - ETA: 0s - loss: 0.8126 - accuracy: 0.6627 - iou: 0.3330
# Epoch 3: val_iou did not improve from 0.37519
# 128/128 [==============================] - 110s 848ms/step - loss: 0.8126 - accuracy: 0.6627 - iou: 0.3330 - val_loss: 0.8629 - val_accuracy: 0.6876 - val_iou: 0.3554
# Epoch 4/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7558 - accuracy: 0.6825 - iou: 0.3517
# Epoch 4: val_iou improved from 0.37519 to 0.39653, saving model to segmentation_unet.h5
# 128/128 [==============================] - 111s 853ms/step - loss: 0.7558 - accuracy: 0.6825 - iou: 0.3517 - val_loss: 0.7995 - val_accuracy: 0.7459 - val_iou: 0.3965
# Epoch 5/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.7124 - iou: 0.3763
# Epoch 5: val_iou improved from 0.39653 to 0.40163, saving model to segmentation_unet.h5
# 128/128 [==============================] - 112s 859ms/step - loss: 0.7023 - accuracy: 0.7124 - iou: 0.3763 - val_loss: 0.7181 - val_accuracy: 0.7516 - val_iou: 0.4016
# Epoch 6/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6908 - accuracy: 0.7144 - iou: 0.3799
# Epoch 6: val_iou did not improve from 0.40163
# 128/128 [==============================] - 97s 743ms/step - loss: 0.6908 - accuracy: 0.7144 - iou: 0.3799 - val_loss: 0.8066 - val_accuracy: 0.7259 - val_iou: 0.3882
# Epoch 7/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7104 - accuracy: 0.7102 - iou: 0.3748
# Epoch 7: val_iou improved from 0.40163 to 0.41370, saving model to segmentation_unet.h5
# 128/128 [==============================] - 97s 741ms/step - loss: 0.7104 - accuracy: 0.7102 - iou: 0.3748 - val_loss: 0.7333 - val_accuracy: 0.7642 - val_iou: 0.4137
# Epoch 8/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6633 - accuracy: 0.7293 - iou: 0.3925
# Epoch 8: val_iou improved from 0.41370 to 0.42047, saving model to segmentation_unet.h5
# 128/128 [==============================] - 98s 749ms/step - loss: 0.6633 - accuracy: 0.7293 - iou: 0.3925 - val_loss: 0.8526 - val_accuracy: 0.7665 - val_iou: 0.4205
# Epoch 9/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6319 - accuracy: 0.7413 - iou: 0.4098
# Epoch 9: val_iou did not improve from 0.42047
# 128/128 [==============================] - 111s 855ms/step - loss: 0.6319 - accuracy: 0.7413 - iou: 0.4098 - val_loss: 0.7849 - val_accuracy: 0.7350 - val_iou: 0.3994
# Epoch 10/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6162 - accuracy: 0.7472 - iou: 0.4299
# Epoch 10: val_iou improved from 0.42047 to 0.46157, saving model to segmentation_unet.h5
# 128/128 [==============================] - 98s 743ms/step - loss: 0.6162 - accuracy: 0.7472 - iou: 0.4299 - val_loss: 0.7198 - val_accuracy: 0.7836 - val_iou: 0.4616
# Epoch 11/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5985 - accuracy: 0.7574 - iou: 0.4512
# Epoch 11: val_iou did not improve from 0.46157
# 128/128 [==============================] - 98s 746ms/step - loss: 0.5985 - accuracy: 0.7574 - iou: 0.4512 - val_loss: 0.7073 - val_accuracy: 0.7938 - val_iou: 0.4542
# Epoch 12/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.7666 - iou: 0.4722
# Epoch 12: val_iou improved from 0.46157 to 0.46695, saving model to segmentation_unet.h5
# 128/128 [==============================] - 99s 754ms/step - loss: 0.5756 - accuracy: 0.7666 - iou: 0.4722 - val_loss: 0.6922 - val_accuracy: 0.7891 - val_iou: 0.4669
# Epoch 13/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5759 - accuracy: 0.7706 - iou: 0.4820
# Epoch 13: val_iou improved from 0.46695 to 0.47492, saving model to segmentation_unet.h5
# 128/128 [==============================] - 114s 878ms/step - loss: 0.5759 - accuracy: 0.7706 - iou: 0.4820 - val_loss: 0.6349 - val_accuracy: 0.7868 - val_iou: 0.4749
# Epoch 14/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5578 - accuracy: 0.7770 - iou: 0.4905
# Epoch 14: val_iou improved from 0.47492 to 0.49213, saving model to segmentation_unet.h5
# 128/128 [==============================] - 99s 761ms/step - loss: 0.5578 - accuracy: 0.7770 - iou: 0.4905 - val_loss: 0.6179 - val_accuracy: 0.7995 - val_iou: 0.4921
# Epoch 15/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.7920 - iou: 0.5076
# Epoch 15: val_iou did not improve from 0.49213
# 128/128 [==============================] - 97s 740ms/step - loss: 0.5232 - accuracy: 0.7920 - iou: 0.5076 - val_loss: 0.6047 - val_accuracy: 0.7901 - val_iou: 0.4883
# Epoch 16/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5137 - accuracy: 0.7968 - iou: 0.5249
# Epoch 16: val_iou did not improve from 0.49213
# 128/128 [==============================] - 97s 743ms/step - loss: 0.5137 - accuracy: 0.7968 - iou: 0.5249 - val_loss: 0.7300 - val_accuracy: 0.7642 - val_iou: 0.4627
# Epoch 17/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.8057 - iou: 0.5322
# Epoch 17: val_iou did not improve from 0.49213
# 128/128 [==============================] - 111s 850ms/step - loss: 0.4935 - accuracy: 0.8057 - iou: 0.5322 - val_loss: 0.6505 - val_accuracy: 0.7841 - val_iou: 0.4911
# Epoch 18/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.8194 - iou: 0.5466
# Epoch 18: val_iou improved from 0.49213 to 0.49552, saving model to segmentation_unet.h5
# 128/128 [==============================] - 112s 862ms/step - loss: 0.4636 - accuracy: 0.8194 - iou: 0.5466 - val_loss: 0.6105 - val_accuracy: 0.7937 - val_iou: 0.4955
# Epoch 19/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.8246 - iou: 0.5548
# Epoch 19: val_iou improved from 0.49552 to 0.52173, saving model to segmentation_unet.h5
# 128/128 [==============================] - 99s 758ms/step - loss: 0.4490 - accuracy: 0.8246 - iou: 0.5548 - val_loss: 0.5515 - val_accuracy: 0.8126 - val_iou: 0.5217
# Epoch 20/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4345 - accuracy: 0.8321 - iou: 0.5753
# Epoch 20: val_iou did not improve from 0.52173
# 128/128 [==============================] - 97s 740ms/step - loss: 0.4345 - accuracy: 0.8321 - iou: 0.5753 - val_loss: 0.6259 - val_accuracy: 0.7843 - val_iou: 0.4921
# Epoch 21/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.8230 - iou: 0.5530
# Epoch 21: val_iou improved from 0.52173 to 0.52486, saving model to segmentation_unet.h5
# 128/128 [==============================] - 114s 873ms/step - loss: 0.4601 - accuracy: 0.8230 - iou: 0.5530 - val_loss: 0.5695 - val_accuracy: 0.8116 - val_iou: 0.5249
# Epoch 22/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4107 - accuracy: 0.8413 - iou: 0.5889
# Epoch 22: val_iou improved from 0.52486 to 0.53021, saving model to segmentation_unet.h5
# 128/128 [==============================] - 99s 757ms/step - loss: 0.4107 - accuracy: 0.8413 - iou: 0.5889 - val_loss: 0.5516 - val_accuracy: 0.8194 - val_iou: 0.5302
# Epoch 23/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4108 - accuracy: 0.8411 - iou: 0.5938
# Epoch 23: val_iou did not improve from 0.53021
# 128/128 [==============================] - 113s 867ms/step - loss: 0.4108 - accuracy: 0.8411 - iou: 0.5938 - val_loss: 0.5640 - val_accuracy: 0.8049 - val_iou: 0.5089
# Epoch 24/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4157 - accuracy: 0.8393 - iou: 0.5858
# Epoch 24: val_iou did not improve from 0.53021
# 128/128 [==============================] - 98s 745ms/step - loss: 0.4157 - accuracy: 0.8393 - iou: 0.5858 - val_loss: 0.6099 - val_accuracy: 0.8034 - val_iou: 0.5180
# Epoch 25/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3913 - accuracy: 0.8494 - iou: 0.5870
# Epoch 25: val_iou improved from 0.53021 to 0.53523, saving model to segmentation_unet.h5
# 128/128 [==============================] - 113s 870ms/step - loss: 0.3913 - accuracy: 0.8494 - iou: 0.5870 - val_loss: 0.5802 - val_accuracy: 0.8251 - val_iou: 0.5352
# Epoch 26/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.8491 - iou: 0.5998
# Epoch 26: val_iou did not improve from 0.53523
# 128/128 [==============================] - 97s 740ms/step - loss: 0.3901 - accuracy: 0.8491 - iou: 0.5998 - val_loss: 0.5285 - val_accuracy: 0.8236 - val_iou: 0.5280
# Epoch 27/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3747 - accuracy: 0.8553 - iou: 0.6125
# Epoch 27: val_iou improved from 0.53523 to 0.54224, saving model to segmentation_unet.h5
# 128/128 [==============================] - 111s 851ms/step - loss: 0.3747 - accuracy: 0.8553 - iou: 0.6125 - val_loss: 0.5855 - val_accuracy: 0.8290 - val_iou: 0.5422
# Epoch 28/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8577 - iou: 0.6260
# Epoch 28: val_iou did not improve from 0.54224
# 128/128 [==============================] - 110s 847ms/step - loss: 0.3675 - accuracy: 0.8577 - iou: 0.6260 - val_loss: 0.6320 - val_accuracy: 0.7989 - val_iou: 0.5129
# Epoch 29/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.8611 - iou: 0.6298
# Epoch 29: val_iou did not improve from 0.54224
# 128/128 [==============================] - 96s 736ms/step - loss: 0.3609 - accuracy: 0.8611 - iou: 0.6298 - val_loss: 0.5625 - val_accuracy: 0.8195 - val_iou: 0.5373
# Epoch 30/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3507 - accuracy: 0.8640 - iou: 0.6291
# Epoch 30: val_iou improved from 0.54224 to 0.54791, saving model to segmentation_unet.h5
# 128/128 [==============================] - 111s 851ms/step - loss: 0.3507 - accuracy: 0.8640 - iou: 0.6291 - val_loss: 0.6117 - val_accuracy: 0.8298 - val_iou: 0.5479
# Epoch 31/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8679 - iou: 0.6442
# Epoch 31: val_iou did not improve from 0.54791
# 128/128 [==============================] - 110s 844ms/step - loss: 0.3419 - accuracy: 0.8679 - iou: 0.6442 - val_loss: 0.7563 - val_accuracy: 0.7833 - val_iou: 0.5014
# Epoch 32/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3420 - accuracy: 0.8681 - iou: 0.6477
# Epoch 32: val_iou did not improve from 0.54791
# 128/128 [==============================] - 95s 726ms/step - loss: 0.3420 - accuracy: 0.8681 - iou: 0.6477 - val_loss: 0.6045 - val_accuracy: 0.8236 - val_iou: 0.5417
# Epoch 33/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3376 - accuracy: 0.8700 - iou: 0.6460
# Epoch 33: val_iou did not improve from 0.54791
# 128/128 [==============================] - 95s 723ms/step - loss: 0.3376 - accuracy: 0.8700 - iou: 0.6460 - val_loss: 0.6348 - val_accuracy: 0.8296 - val_iou: 0.5468
# Epoch 34/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.8751 - iou: 0.6600
# Epoch 34: val_iou did not improve from 0.54791
# 128/128 [==============================] - 96s 730ms/step - loss: 0.3236 - accuracy: 0.8751 - iou: 0.6600 - val_loss: 0.6140 - val_accuracy: 0.8111 - val_iou: 0.5336
# Epoch 35/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8768 - iou: 0.6556
# Epoch 35: val_iou improved from 0.54791 to 0.55091, saving model to segmentation_unet.h5
# 128/128 [==============================] - 97s 740ms/step - loss: 0.3187 - accuracy: 0.8768 - iou: 0.6556 - val_loss: 0.5602 - val_accuracy: 0.8294 - val_iou: 0.5509
# Epoch 36/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8844 - iou: 0.6838
# Epoch 36: val_iou did not improve from 0.55091
# 128/128 [==============================] - 96s 736ms/step - loss: 0.2988 - accuracy: 0.8844 - iou: 0.6838 - val_loss: 0.6155 - val_accuracy: 0.8311 - val_iou: 0.5480
# Epoch 37/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8863 - iou: 0.6786
# Epoch 37: val_iou did not improve from 0.55091
# 128/128 [==============================] - 96s 735ms/step - loss: 0.2946 - accuracy: 0.8863 - iou: 0.6786 - val_loss: 0.6468 - val_accuracy: 0.8260 - val_iou: 0.5460
# Epoch 38/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.8884 - iou: 0.6885
# Epoch 38: val_iou did not improve from 0.55091
# 128/128 [==============================] - 96s 732ms/step - loss: 0.2874 - accuracy: 0.8884 - iou: 0.6885 - val_loss: 0.6461 - val_accuracy: 0.8243 - val_iou: 0.5421
# Epoch 39/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.8914 - iou: 0.6915
# Epoch 39: val_iou did not improve from 0.55091
# 128/128 [==============================] - 111s 851ms/step - loss: 0.2809 - accuracy: 0.8914 - iou: 0.6915 - val_loss: 0.6557 - val_accuracy: 0.8318 - val_iou: 0.5487
# Epoch 40/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.8893 - iou: 0.6948
# Epoch 40: val_iou did not improve from 0.55091
# 128/128 [==============================] - 112s 859ms/step - loss: 0.2878 - accuracy: 0.8893 - iou: 0.6948 - val_loss: 0.5738 - val_accuracy: 0.8273 - val_iou: 0.5493
# Epoch 41/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.8890 - iou: 0.6950
# Epoch 41: val_iou did not improve from 0.55091
# 128/128 [==============================] - 97s 745ms/step - loss: 0.2886 - accuracy: 0.8890 - iou: 0.6950 - val_loss: 0.5901 - val_accuracy: 0.8257 - val_iou: 0.5462
# Epoch 42/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8969 - iou: 0.7242
# Epoch 42: val_iou did not improve from 0.55091
# 128/128 [==============================] - 97s 742ms/step - loss: 0.2683 - accuracy: 0.8969 - iou: 0.7242 - val_loss: 0.7536 - val_accuracy: 0.8117 - val_iou: 0.5259
# Epoch 43/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8985 - iou: 0.7119
# Epoch 43: val_iou improved from 0.55091 to 0.55145, saving model to segmentation_unet.h5
# 128/128 [==============================] - 113s 865ms/step - loss: 0.2637 - accuracy: 0.8985 - iou: 0.7119 - val_loss: 0.6409 - val_accuracy: 0.8281 - val_iou: 0.5514
# Epoch 44/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9060 - iou: 0.7505
# Epoch 44: val_iou did not improve from 0.55145
# 128/128 [==============================] - 111s 851ms/step - loss: 0.2428 - accuracy: 0.9060 - iou: 0.7505 - val_loss: 0.6952 - val_accuracy: 0.8255 - val_iou: 0.5493
# Epoch 45/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.9093 - iou: 0.7038
# Epoch 45: val_iou did not improve from 0.55145
# 128/128 [==============================] - 111s 854ms/step - loss: 0.2361 - accuracy: 0.9093 - iou: 0.7038 - val_loss: 0.6874 - val_accuracy: 0.8215 - val_iou: 0.5452
# Epoch 46/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2685 - accuracy: 0.8979 - iou: 0.7001
# Epoch 46: val_iou did not improve from 0.55145
# 128/128 [==============================] - 96s 736ms/step - loss: 0.2685 - accuracy: 0.8979 - iou: 0.7001 - val_loss: 0.6220 - val_accuracy: 0.8107 - val_iou: 0.5249
# Epoch 47/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.8954 - iou: 0.6845
# Epoch 47: val_iou did not improve from 0.55145
# 128/128 [==============================] - 94s 720ms/step - loss: 0.2782 - accuracy: 0.8954 - iou: 0.6845 - val_loss: 0.7142 - val_accuracy: 0.8060 - val_iou: 0.5289
# Epoch 48/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9113 - iou: 0.7400
# Epoch 48: val_iou did not improve from 0.55145
# 128/128 [==============================] - 95s 723ms/step - loss: 0.2304 - accuracy: 0.9113 - iou: 0.7400 - val_loss: 0.7047 - val_accuracy: 0.8206 - val_iou: 0.5435
# Epoch 49/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.9121 - iou: 0.7359
# Epoch 49: val_iou did not improve from 0.55145
# 128/128 [==============================] - 95s 725ms/step - loss: 0.2278 - accuracy: 0.9121 - iou: 0.7359 - val_loss: 0.6670 - val_accuracy: 0.8228 - val_iou: 0.5384
# Epoch 50/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.9207 - iou: 0.7660
# Epoch 50: val_iou did not improve from 0.55145
# 128/128 [==============================] - 94s 720ms/step - loss: 0.2057 - accuracy: 0.9207 - iou: 0.7660 - val_loss: 0.7430 - val_accuracy: 0.8212 - val_iou: 0.5311
# Epoch 51/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9204 - iou: 0.7731
# Epoch 51: val_iou improved from 0.55145 to 0.55150, saving model to segmentation_unet.h5
# 128/128 [==============================] - 96s 734ms/step - loss: 0.2068 - accuracy: 0.9204 - iou: 0.7731 - val_loss: 0.6869 - val_accuracy: 0.8270 - val_iou: 0.5515
# Epoch 52/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9234 - iou: 0.7711
# Epoch 52: val_iou did not improve from 0.55150
# 128/128 [==============================] - 95s 728ms/step - loss: 0.1979 - accuracy: 0.9234 - iou: 0.7711 - val_loss: 0.7520 - val_accuracy: 0.8218 - val_iou: 0.5459
# Epoch 53/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9271 - iou: 0.7837
# Epoch 53: val_iou did not improve from 0.55150
# 128/128 [==============================] - 109s 833ms/step - loss: 0.1880 - accuracy: 0.9271 - iou: 0.7837 - val_loss: 0.8372 - val_accuracy: 0.8165 - val_iou: 0.5408
# Epoch 54/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9268 - iou: 0.7789
# Epoch 54: val_iou did not improve from 0.55150
# 128/128 [==============================] - 109s 833ms/step - loss: 0.1903 - accuracy: 0.9268 - iou: 0.7789 - val_loss: 0.8036 - val_accuracy: 0.8128 - val_iou: 0.5372
# Epoch 55/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.9085 - iou: 0.7152
# Epoch 55: val_iou did not improve from 0.55150
# 128/128 [==============================] - 96s 734ms/step - loss: 0.2500 - accuracy: 0.9085 - iou: 0.7152 - val_loss: 0.6047 - val_accuracy: 0.8269 - val_iou: 0.5475
# Epoch 56/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9214 - iou: 0.7612
# Epoch 56: val_iou did not improve from 0.55150
# 128/128 [==============================] - 111s 851ms/step - loss: 0.2082 - accuracy: 0.9214 - iou: 0.7612 - val_loss: 0.7313 - val_accuracy: 0.8152 - val_iou: 0.5349
# Epoch 56: early stopping

# %% [markdown]
# ### Load trained model

# %%
model_unet.load_weights("segmentation_unet.h5")

# %% [markdown]
# ## Model evaluation
# Let's compute the metrics and loss function values for the trained model.

# %%
data_gen_test = DataGenerator(batch_size=batch_size,
                              patch_size=patch_size,
                              step_size=step_size,
                              list_top=list_top_test, 
                              list_gts=list_gts_test,
                              n_classes=n_classes,
                              colormap_gt=color2index
                              )

print("Train:")
scores_train = model_unet.evaluate(data_gen_train)

print("Validation:")
scores_val = model_unet.evaluate(data_gen_val)

print("Test:")
scores_test = model_unet.evaluate(data_gen_test)
# Out:
# Train:
# 128/128 [==============================] - 72s 558ms/step - loss: 0.1545 - accuracy: 0.9399 - iou: 0.8110
# Validation:
# 38/38 [==============================] - 20s 522ms/step - loss: 0.6869 - accuracy: 0.8270 - iou: 0.5515
# Test:
# 190/190 [==============================] - 127s 667ms/step - loss: 0.6660 - accuracy: 0.8200 - iou: 0.5788

# %% [markdown]
# ## Visualization of the predictions

# %%
#@title Predictions Visualization { run: "auto"}
#@markdown Select a sample
id_batch = 107 #@param {type:"slider", min:0, max:189, step:1}

# Get a batch from the generator for testing
x,y = data_gen_test.__getitem__(id_batch)
# Obtain the prediction from the trained model
prediction = model_unet.predict(x)
# Iterate over each sample in the batch
for x_i,y_i,pred_i in zip(x,y,prediction):
  # For visualization: [0,1] => [0,255]
  x_i = x_i*255
  x_i = x_i.astype(np.uint8)
  # From one hot encoding to integer
  gt = np.argmax(y_i, axis=-1)
  pred = np.argmax(pred_i, axis=-1)
  # Object to compute the mean IoU
  m_iou = OneHotMeanIoU(num_classes=n_classes)
  m_iou.update_state(y_true=y_i, 
                     y_pred=pred_i)
  # List to storage IoU per class
  iou_all = []
  for id_class in range(n_classes):
    # Object to compute the IoU for each class
    m_iou_class = OneHotIoU(num_classes=n_classes, 
                            target_class_ids=[id_class])
    m_iou_class.update_state(y_true=y_i, 
                             y_pred=pred_i)
    # Save IoU for each class
    iou_all.append(m_iou_class.result().numpy())
  # Colo images for the Ground Truth and Prediction
  gt_rgb = np.zeros((gt.shape[0],gt.shape[1],3), dtype=np.uint8)
  pred_rgb = np.zeros((gt.shape[0],gt.shape[1],3), dtype=np.uint8)
  # Assign a color to each integer value from the given dictionary
  for key,value in color2index.items():
    gt_rgb[gt==value] = key
    pred_rgb[pred==value] = key
  # Visualization
  plt.figure(figsize=(10,3))
  plt.subplot(1,4,1)
  plt.imshow(x_i)
  plt.title("RGB image")
  plt.axis("off")

  plt.subplot(1,4,2)
  plt.imshow(gt_rgb)
  plt.title("Reference")
  plt.axis("off")

  plt.subplot(1,4,3)
  plt.imshow(pred_rgb)
  plt.title("Prediction\nmIoU={:.2f}\n{}".format(m_iou.result().numpy(),
                                                 np.round(iou_all, decimals=2)))
  plt.axis("off")

  g = plt.subplot(1,4,4)
  g.axes.set_xlim(0,3.4)
  g.axes.set_ylim(-0.01,0.55)

  g.text(0, 0.025, "Impervious surfaces")
  g.text(0, 0.125, "Building ")
  g.text(0, 0.225, "Low vegetation")
  g.text(0, 0.325, "Tree ")
  g.text(0, 0.425, "Car ")
  g.text(0, 0.525, "Clutter/background")

  x_rec = 2.3
  g.add_patch(patches.Rectangle((x_rec,0.0), 1, 0.05, facecolor="#FFFFFF", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.1), 1, 0.05, facecolor="#0000FF", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.2), 1, 0.05, facecolor="#00FFFF", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.3), 1, 0.05, facecolor="#00FF00", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.4), 1, 0.05, facecolor="#FFFF00", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.5), 1, 0.05, facecolor="#FF0000", edgecolor="black"))
  g.axis("off")

  plt.tight_layout()

  plt.show()

# %% [markdown]
# ## Assignment

# %% [markdown]
# Compare the results obtained by using Transpose Convolution and Unpooling.
#
# - Replace Transpose Convolution layer:
# ```python
# Conv2DTranspose(filters=filters,
#                 kernel_size=3,
#                 strides=2,
#                 padding="same")
# ```
#   by Unpooling:
#
#   ```python
#   UpSampling2D(size=(2, 2),
#                 interpolation="nearest")
#
#   ```
# - Compare number of parameters:
# - Train U-Net
# - Visualize your results

# %% [markdown]
# - With Conv2DTranspos, it has 8,557,830 parameters
# - With UpSampling2D, it has 7,783,238 parameters. it decresses almost 10 %.
